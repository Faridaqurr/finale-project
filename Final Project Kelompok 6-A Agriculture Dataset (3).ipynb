# %% [markdown]
# ## Kelompok 6 - Kelas A

# %% [markdown]
# **Mata Kuliah : Statistika dan Probabilitas**

# %% [markdown]
# - Revalina Fairuzy Azhari Putri / 5027231001
# - Farida Qurrotu A'yuna / 5027231015
# - Nayyara Ashila / 5027231083

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# # Dataset

# %% [markdown]
# Menggunakan dataset asli _open-source_ yang tersedia pada kaggle, dengan deskripsi :

# %% [markdown]
# **- Nama Dataset :** AgriSeshat: Agriculture Dataset

# %% [markdown]
# **- Deskripsi :** The Seshat: Global History Databank is an international scientific research project of the nonprofit Evolution Institute. Founded in 2011, the Seshat: Global History Databank gathers data into a single, large database that can be used to test scientific hypotheses. The Databank consults directly with expert scholars to code what historical societies and their environments were like in the form of accessible datapoints and thus forms a digital storehouse for data on the political and social organization of all human groups from the early modern back to the ancient and neolithic periods.The organizers of this research project contend that the mass of data then can be used to test a variety of competing hypotheses about the rise and fall of large-scale societies around the globe which may help science provide answers to global problems.

# %% [markdown]
# **- Daftar Atribut :**

# %%
import pandas as pd

# Membuat DataFrame
data = {
    'Atribut': ['NGA', 'Variable', 'Value From & Value To', 'Value Note', 'Date From & Date To', 'Unit', 'Explanation'],
    'Deskripsi': [
        'Name of the location or region. Examples include "Big Island Hawaii" and "Yemeni Coastal Plain.").',
        'Specific type of data or variable. Examples include "Carbohydrate Source," "Cropping System," "Cropping System Coefficient," "Fertilizer Coefficient," and so on.',
        'Range of values or quantities for a specific variable. For example, for "Carbohydrate Source," the value is "weet potato" with a range from 0 to 0.',
        'Additional notes or explanations about a specific value or variable.',
        'Time range or dates associated with the data. For example, "750" to "1800" or "-1500" to "2000.',
        'Measurement unit used, such as "0" or "inferred.',
        'Additional explanation about a specific variable or data.',
    ]
}
Agriculture_Daset_daftar_atribut = pd.DataFrame(data)
print(Agriculture_Daset_daftar_atribut)
# Out:
#                  Atribut                                          Deskripsi
# 0                    NGA  Name of the location or region. Examples inclu...
# 1               Variable  Specific type of data or variable. Examples in...
# 2  Value From & Value To  Range of values or quantities for a specific v...
# 3             Value Note  Additional notes or explanations about a speci...
# 4    Date From & Date To  Time range or dates associated with the data. ...
# 5                   Unit   Measurement unit used, such as "0" or "inferred.
# 6            Explanation  Additional explanation about a specific variab...

# %% [markdown]
# **- Jumlah Kolom :** 9

# %% [markdown]
# **- Jumlah Baris :** 330

# %% [markdown]
# **- Sumber :** https://www.kaggle.com/datasets/usharengaraju/agriseshat-agriculture-dataset

# %% [markdown]
# # Tujuan Analisis

# %% [markdown]
# Memahami data pertanian yang terdapat dalam dataset, termasuk jenis tanaman, variabel-variabel lingkungan, dan data terkait pertanian lainnya.

# %% [markdown]
# # 1. Memahami Dataset

# %% [markdown]
# # a. Memuat Dataset

# %% [markdown]
# Dataset berbentuk CSV, diimport menggunakan library Pandas dengan bahasa pemrograman Python.

# %%
# import library 
import pandas as pd

# load dataset 
Agriculture_Dataset = pd.read_csv('Agriculture.csv')

# %% [markdown]
# # b. Menampilkan Dataset

# %% [markdown]
# Melihat beberapa baris data untuk memahami struktur dan formatnya secara sekilas.

# %%
# menampilkan dataset
Agriculture_Dataset
# Out:
#                       NGA                     Variable    Value From Value To  \
# 0       Big Island Hawaii        Carbohydrate Source 1  sweet potato      NaN
# 1       Big Island Hawaii              Cropping System       swidden      NaN
# 2       Big Island Hawaii  Cropping System Coefficient          0.23      NaN
# 3       Big Island Hawaii       Fertilizer Coefficient           1.3      NaN
# 4       Big Island Hawaii                  Fertilizers       present      NaN
# ..                    ...                          ...           ...      ...
# 325  Yemeni Coastal Plain  Cropping System Coefficient             1      NaN
# 326  Yemeni Coastal Plain       Fertilizer Coefficient          1.65      NaN
# 327  Yemeni Coastal Plain                  Fertilizers       present      NaN
# 328  Yemeni Coastal Plain                   Irrigation       present      NaN
# 329  Yemeni Coastal Plain       Irrigation Coefficient          1.48      NaN
#
# ...

# %% [markdown]
# Terlihat bahwa dataset memuat 330 baris dan 9 kolom.

# %%
Agriculture_Dataset.head()
# Out:
#                  NGA                     Variable    Value From Value To  \
# 0  Big Island Hawaii        Carbohydrate Source 1  sweet potato      NaN
# 1  Big Island Hawaii              Cropping System       swidden      NaN
# 2  Big Island Hawaii  Cropping System Coefficient          0.23      NaN
# 3  Big Island Hawaii       Fertilizer Coefficient           1.3      NaN
# 4  Big Island Hawaii                  Fertilizers       present      NaN
#
#   Value Note  Date From  Date To Unit  \
# 0        NaN        750     1800  NaN
# 1        NaN        750     1400  NaN
# 2   inferred        750     1400  NaN
# 3        NaN        750     1900  NaN
# 4   inferred        750     1800  NaN
#
#                                          Explanation
# 0  Sweet potato was the the dominant crop in the ...
# 1  Shifting cultivation (in the form of swidden a...
# 2                                   Generic estimate
# 3         Assuming 30% while looking for an estimate
# ...

# %% [markdown]
# Menampilkan 5 sampel data teratas

# %% [markdown]
# # c. Mengidentifikasi Atribut

# %% [markdown]
# Mengidentifikasi jenis-jenis atribut pada data, tipe data setiap atribut, dan arti dari setiap atribut.

# %%
Agriculture_Dataset.columns.values.tolist()
# Out:
# ['NGA',
#  'Variable',
#  'Value From',
#  'Value To',
#  'Value Note',
#  'Date From',
#  'Date To',
#  'Unit',
#  'Explanation']

# %% [markdown]
# Mengidentifikasi list dari nama atribut.

# %%
Agriculture_Dataset.dtypes
# Out:
# NGA            object
# Variable       object
# Value From     object
# Value To       object
# Value Note     object
# Date From       int64
# Date To         int64
# Unit           object
# Explanation    object
# dtype: object

# %% [markdown]
# Mengidentifikasi tipe data dari setiap atribut

# %% [markdown]
# Berikut adalah deskripsi atribut/kolom untuk dataset ini.

# %%
import pandas as pd

# Membuat DataFrame
data = {
    'Atribut': ['NGA', 'Variable', 'Value From & Value To', 'Value Note', 'Date From & Date To', 'Unit', 'Explanation'],
    'Deskripsi': [
        'Nama lokasi atau wilayah. Contohnya, "Big Island Hawaii" dan "Yemeni Coastal Plain."',
        'Variabel atau jenis data tertentu. Contohnya, "Carbohydrate Source," "Cropping System," "Cropping System Coefficient," "Fertilizer Coefficient," dll.',
        'Rentang nilai atau kuantitas untuk variabel tertentu. Misalnya, untuk "Carbohydrate Source," nilainya adalah "sweet potato" dengan rentang nilai dari 0 hingga 0.',
        'Catatan atau penjelasan tambahan mengenai nilai atau variabel tertentu.',
        'Rentang waktu atau tanggal yang terkait dengan data tersebut. Contohnya, "750" hingga "1800" atau "-1500" hingga "2000."',
        'Unit pengukuran yang digunakan, seperti "0" atau "inferred."',
        'Penjelasan tambahan mengenai variabel atau data tertentu.'
    ]
}
Agriculture_Dataset_daftar_atribut = pd.DataFrame(data)
print(Agriculture_Daset_daftar_atribut)
# Out:
#                  Atribut                                          Deskripsi
# 0                    NGA  Nama lokasi atau wilayah. Contohnya, "Big Isla...
# 1               Variable  Variabel atau jenis data tertentu. Contohnya, ...
# 2  Value From & Value To  Rentang nilai atau kuantitas untuk variabel te...
# 3             Value Note  Catatan atau penjelasan tambahan mengenai nila...
# 4    Date From & Date To  Rentang waktu atau tanggal yang terkait dengan...
# 5                   Unit  Unit pengukuran yang digunakan, seperti "0" at...
# 6            Explanation  Penjelasan tambahan mengenai variabel atau dat...

# %% [markdown]
# Terdapat beberapa atribut yang mungkin saja dapat mempengaruhi data pertanian, yaitu:

# %% [markdown]
# **- Variable**

# %% [markdown]
# **- Value From**

# %% [markdown]
# **- Value To**

# %% [markdown]
# **- Value Note**

# %% [markdown]
# **- Date From**

# %% [markdown]
# **- Date To**

# %% [markdown]
# **- Unit**

# %% [markdown]
# ### 1) Variable

# %% [markdown]
# Atribut "Variable" berisi data dengan tipe data _object_ atau string atau karakter. Sehingga, ada beberapa hal yang dapat kita identifikasi dari atribut ini.

# %%
Agriculture_Dataset['Variable'].unique().tolist()
# Out:
# ['Carbohydrate Source 1',
#  'Cropping System',
#  'Cropping System Coefficient',
#  'Fertilizer Coefficient',
#  'Fertilizers',
#  'Irrigation',
#  'Historical Productivity',
#  'Irrigation Coefficient',
#  'HIstorical Productivity']

# %% [markdown]
# ### 2) Value From, Value To, Value Note

# %% [markdown]
# Atribut "Value From", "Value To", dan "Value Note" berisi data dengan tipe data _object_ atau string atau karakter. Sehingga, ada beberapa hal yang dapat kita identifikasi dari atribut ini. Di sisi lain, Atribut ini terdiri dari 3 kolom yang sepertinya saling berhubungan.

# %% [markdown]
# _Value From_

# %%
Agriculture_Dataset['Value From'].unique().tolist()
# Out:
# ['sweet potato',
#  'swidden',
#  '0.23',
#  '1.3',
#  'present',
#  'absent',
#  'no fallow ',
#  '1',
#  '3.25',
#  '1.16',
#  'chenopod',
#  '1.66',
#  'maize',
#  'two-field',
#  '0.5',
#  '0.672',
#  'rice',
#  'short-fallow',
#  '0.75',
#  '1.46',
#  '2.5',
#  '1.345',
#  'breadfruit',
#  '0.12',
#  '16',
#  'unknown',
#  '10',
#  '1.08',
#  '1.2',
#  'millet',
#  '0.2',
#  '1.11',
#  '1.48',
#  '1.65',
#  '1.371',
#  '0.125',
#  'yams',
#  '0.167',
#  '1.94',
#  'none',
#  '0',
#  'barley',
#  'wheat',
#  'long fallow',
#  '0.33',
#  '1.096',
#  'multi-cropping',
#  '2',
#  '1.55',
#  '1.5',
#  '1.9',
#  '2.1',
#  '2.2',
#  '0.055',
#  '0.376',
#  '1.296',
#  '1.35',
#  '0.54',
#  '0.675',
#  '0.878',
#  '0.405',
#  'cassava',
#  '0.258',
#  '1.05',
#  '0.8',
#  '0.25',
#  'pearl millet',
#  'taro',
#  '0.045',
#  '6.5',
#  '0.65',
#  '0.308',
#  'three-field',
#  '0.67',
#  '0.773',
#  '1.624',
#  '1.933',
#  '2.22',
#  'irrigation',
#  '0.1',
#  '0.375',
#  '0.574',
# ...

# %% [markdown]
# _Value To_

# %%
Agriculture_Dataset['Value To'].unique().tolist()
# Out:
# [nan,
#  'no fallow ',
#  '1.681',
#  '0.17',
#  '32',
#  '14',
#  '1.5',
#  '0.286',
#  '0.301',
#  '0.33',
#  '1',
#  '0.214',
#  '0.525',
#  '1.62',
#  '2.43',
#  '0.648',
#  '0.535',
#  '1.134',
#  '0.81',
#  '1.053',
#  '3.24',
#  '1.35',
#  'two-field',
#  '0.5',
#  '3.5',
#  '0.333',
#  '7',
#  'present',
#  '0.8',
#  '0.557',
#  '1.701',
#  '1.546',
#  'barley',
#  '0.666',
#  '0.976',
#  '1.46',
#  '0.93',
#  '0.6',
#  '1.1',
#  '1.4',
#  '1.9']

# %%
Agriculture_Dataset['Value Note'].unique().tolist()
# Out:
# [nan, 'inferred', 'uncertain', 'disputed', 'Average=0.4']

# %%
import pprint

# function to get unique values
def unique(mylist):
    unique_list = []
    for x in mylist:
        # check if exists in unique_list or not
        if x not in unique_list:
            unique_list.append(x)

    pprint.pprint(unique_list)

# %%
unique(list(zip(Agriculture_Dataset['Value From'],Agriculture_Dataset['Value To'], Agriculture_Dataset['Value Note'])))
# Out:
# [('sweet potato', nan, nan),
#  ('swidden', nan, nan),
#  ('0.23', nan, 'inferred'),
#  ('1.3', nan, nan),
#  ('present', nan, 'inferred'),
#  ('absent', nan, nan),
#  ('no fallow ', nan, nan),
#  ('1', nan, 'inferred'),
#  ('3.25', nan, nan),
#  ('present', nan, nan),
#  ('1.16', nan, nan),
#  ('chenopod', nan, nan),
#  ('swidden', nan, 'uncertain'),
#  ('0.23', nan, nan),
#  ('1.66', nan, nan),
#  ('maize', nan, nan),
#  ('two-field', 'no fallow ', 'uncertain'),
#  ('0.5', nan, 'inferred'),
#  ('0.672', '1.681', nan),
#  ('rice', nan, nan),
#  ('swidden', nan, 'inferred'),
#  ('short-fallow', nan, nan),
#  ('0.75', nan, nan),
#  ('1.46', nan, nan),
#  ('2.5', nan, nan),
#  ('1.3', nan, 'inferred'),
#  ('swidden', 'no fallow ', nan),
#  ('0.5', nan, nan),
#  ('1.345', '1.681', nan),
#  ('breadfruit', nan, nan),
#  ('0.12', '0.17', nan),
#  ('16', '32', nan),
#  ('unknown', nan, nan),
#  ('10', '14', nan),
#  ('maize', nan, 'inferred'),
#  ('absent', nan, 'inferred'),
# ...

# %% [markdown]
# ### 3) Date From, Date To

# %% [markdown]
# Atribut "Date From" dan "Date To" berisi data dengan tipe data _int_ atau bilangan bulat. Kita perlu mengidentifikasi apakah atribut ini memiliki nilai yang aneh dengan mengabaikan nilai distinct-nya karena pasti sangat banyak.

# %% [markdown]
# _Date From_

# %%
Agriculture_Dataset['Date From'].isnull().values.any()
# Out:
# False

# %% [markdown]
# _Date To_

# %%
Agriculture_Dataset['Date To'].isnull().values.any()
# Out:
# False

# %% [markdown]
# Tidak ada nilai "null", artinya atribut ini cukup baik.

# %% [markdown]
# ### 4) Unit

# %% [markdown]
# Atribut "Unit" berisi data dengan tipe data object atau string atau karakter. Sehingga, ada beberapa hal yang dapat kita identifikasi dari atribut ini.

# %%
Agriculture_Dataset['Unit'].unique().tolist()
# Out:
# [nan, 't/ha']

# %% [markdown]
# # 2. Statistik Deskriptif

# %% [markdown]
# Statistik deskriptif ada 2, untuk melihat pemusatan data dan penyebaran data.

# %% [markdown]
# **- Pemusatan data:** Mean, median, modus

# %% [markdown]
# **- Penyebaran data:** Varian, standar deviasi

# %%
Agriculture_Dataset.describe()
# Out:
#           Date From      Date To
# count    330.000000   330.000000
# mean   -1536.809091  1059.727273
# std     2867.255946  1447.224197
# min   -10000.000000 -7000.000000
# 25%    -3000.000000   710.000000
# 50%     -800.000000  1810.000000
# 75%      930.000000  1914.250000
# max     2000.000000  2001.000000

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Data statistik deskriptif
data = {
    'Date From': {
        'count': 330.000000,
        'mean': -1536.809091,
        'std': 2867.255946,
        'min': -10000.000000,
        '25%': -3000.000000,
        '50%': -800.000000,
        '75%': 930.000000,
        'max': 2000.000000
    },
    'Date To': {
        'count': 330.000000,
        'mean': 1059.727273,
        'std': 1447.224197,
        'min': -7000.000000,
        '25%': 710.000000,
        '50%': 1810.000000,
        '75%': 1914.250000,
        'max': 2001.000000
    }
}

# Membuat DataFrame dari data
df = pd.DataFrame(data)

# Menentukan kolom yang akan diplot (misalnya, mean, 50%, max)
kolom_diplot = ['mean', '50%', 'max']

# Membuat grafik batang
plt.figure(figsize=(10, 5))
df.T[kolom_diplot].plot(kind='bar', alpha=0.7)
plt.title('Statistik Deskriptif Date From dan Date To')
plt.xlabel('Statistik')
plt.ylabel('Nilai')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# Distribusi data pada kolom "Date From" dan "Date To" memiliki karakteristik simetris, karena nilai mean dan median cenderung berada pada posisi yang hampir sama. Distribusi simetris tidak selalu menandakan bahwa distribusi tersebut adalah distribusi normal. Karena, tidak semua distribusi simetris adalah distribusi normal.

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Data statistik deskriptif
data = {
    'Date From': {
        'count': 330.000000,
        'mean': -1536.809091,
        'std': 2867.255946,
        'min': -10000.000000,
        '25%': -3000.000000,
        '50%': -800.000000,
        '75%': 930.000000,
        'max': 2000.000000
    },
    'Date To': {
        'count': 330.000000,
        'mean': 1059.727273,
        'std': 1447.224197,
        'min': -7000.000000,
        '25%': 710.000000,
        '50%': 1810.000000,
        '75%': 1914.250000,
        'max': 2001.000000
    }
}

# Membuat DataFrame dari data
df = pd.DataFrame(data)

# Kolom yang akan diplot
kolom_diplot = ['min', '25%', '50%', '75%', 'max']

# Membuat grafik bar
plt.figure(figsize=(10, 5))
df.T[kolom_diplot].plot(kind='bar', alpha=0.7, yerr=df.T['std'])
plt.title('Range dan Standar Deviasi Date From dan Date To')
plt.xlabel('Statistik')
plt.ylabel('Nilai')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# - Dalam 'Date From', rentang data terlihat cukup besar, dengan nilai minimum yang sangat rendah dan nilai maksimum yang jauh lebih tinggi. Ini menunjukkan adanya variasi yang signifikan dalam rentang waktu 'Date From'. Standar deviasi yang tinggi juga menegaskan variasi yang besar dalam data ini, menandakan bahwa data tersebar luas dari nilai rata-rata.
#
# - Di sisi lain, 'Date To' memiliki rentang data yang juga cukup luas, meskipun tidak sebesar 'Date From'. Standar deviasi yang lebih rendah pada 'Date To' mengindikasikan bahwa data cenderung lebih terkumpul di sekitar nilai rata-rata. Median dan kuartil bawah dan atas yang lebih tinggi pada 'Date To' menunjukkan bahwa sebagian besar data berada di bagian atas rentang.
#
# - Secara keseluruhan, perbandingan antara 'Date From' dan 'Date To' menunjukkan perbedaan yang signifikan dalam variasi dan sebaran data. 'Date From' memiliki variasi yang lebih besar dan rentang yang lebih luas, sementara 'Date To' lebih terkumpul di sekitar nilai rata-rata dengan variasi yang lebih terkendali.

# %% [markdown]
# # 3. Analisis Data

# %%
# import library 
import pandas as pd

# load dataset 
Agriculture_Dataset = pd.read_csv('Agriculture.csv')

# %%
Agriculture_Dataset
# Out:
#                       NGA                     Variable    Value From Value To  \
# 0       Big Island Hawaii        Carbohydrate Source 1  sweet potato      NaN
# 1       Big Island Hawaii              Cropping System       swidden      NaN
# 2       Big Island Hawaii  Cropping System Coefficient          0.23      NaN
# 3       Big Island Hawaii       Fertilizer Coefficient           1.3      NaN
# 4       Big Island Hawaii                  Fertilizers       present      NaN
# ..                    ...                          ...           ...      ...
# 325  Yemeni Coastal Plain  Cropping System Coefficient             1      NaN
# 326  Yemeni Coastal Plain       Fertilizer Coefficient          1.65      NaN
# 327  Yemeni Coastal Plain                  Fertilizers       present      NaN
# 328  Yemeni Coastal Plain                   Irrigation       present      NaN
# 329  Yemeni Coastal Plain       Irrigation Coefficient          1.48      NaN
#
# ...

# %%
Agriculture_Dataset.NGA.value_counts()
# Out:
# NGA
# Latium                        24
# Paris Basin                   23
# Valley of Oaxaca              20
# Middle Yellow River Valley    19
# Kansai                        17
# Konya Plain                   16
# Kachi Plain                   15
# Cambodian Basin               15
# Cuzco                         14
# Susiana                       12
# Big Island Hawaii             12
# Deccan                        12
# Upper Egypt                   11
# Central Java                  10
# Cahokia                       10
# Niger Inland Delta            10
# Yemeni Coastal Plain           9
# Chuuk Islands                  9
# Finger Lakes                   9
# Sogdiana                       8
# North Colombia                 7
# Lena River Valley              7
# Oro PNG                        6
# Ghanaian Coast                 6
# Southern China Hills           6
# Garo Hills                     6
# Kapuasi Basin                  6
# Lowland Andes                  5
# ...

# %% [markdown]
#  jumlah entri data tertinggi ada pada daerah Latium, dan terendah pada daerah Orkhon Valley

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 10))
sns.lineplot(data=Agriculture_Dataset, y="Date From", x='NGA', color='blue')
plt.xticks(rotation=90)
plt.title('Hubungan antara time dan NGA', fontsize=18, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Hubungan antara time dan NGA')

# %% [markdown]
# Grafik tersebut menunjukkan bahwa praktik pertanian dapat ditelusuri kembali hingga sekitar 10000 Sebelum Masehi

# %%
plt.figure(figsize=(30,30))
g = sns.catplot(x="NGA", y="Date To", kind="box",
            data=Agriculture_Dataset.sort_values("NGA"), palette="tab10")
g.fig.set_figwidth(15)
g.fig.set_figheight(8)
plt.title('NGA vs Date To',fontsize=15, fontweight='bold')
plt.xticks(rotation=90, fontsize=14)
plt.show()
# Out:
# C:\Users\Revalina\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.figure(figsize=(30,30))
g = sns.catplot(x="Variable", y="Date From", kind="boxen",
            data=Agriculture_Dataset.sort_values("NGA"), palette="tab10")
g.fig.set_figwidth(12)
g.fig.set_figheight(8)
plt.title('NGA vs Date From',fontsize=15, fontweight='bold')
plt.xticks(rotation=90, fontsize=14)
plt.show()
# Out:
# C:\Users\Revalina\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Dari grafik - grafik tersebut, dapat dilihat bahwa :
# - Karbohidrat dikonsumsi sejak sekitar 10000 SM.
# - Pupuk diadopsi sebagai bagian dari pertanian sejak sekitar 7500 SM.
# - Irigasi juga mulai digunakan dalam pertanian sejak 8000 SM.
# - Sistem tanam juga diadopsi sekitar 10000 SM.

# %%
Agriculture_Dataset_yield = Agriculture_Dataset[(Agriculture_Dataset.Unit == 't/ha')]

# %%
Agriculture_Dataset_yield
# Out:
#                    NGA                 Variable Value From Value To  \
# 8    Big Island Hawaii  Historical Productivity       3.25      NaN
# 21             Cahokia  Historical Productivity      0.672    1.681
# 33     Cambodian Basin  Historical Productivity       1.46      NaN
# 36     Cambodian Basin  Historical Productivity        2.5      NaN
# 46        Central Java  Historical Productivity      1.345    1.681
# ..                 ...                      ...        ...      ...
# 316   Valley of Oaxaca  Historical Productivity        0.7        1
# 317   Valley of Oaxaca  Historical Productivity        0.8      1.1
# 318   Valley of Oaxaca  Historical Productivity          1      1.4
# 319   Valley of Oaxaca  Historical Productivity        1.1      1.5
# 320   Valley of Oaxaca  Historical Productivity        1.4      1.9
#
#     Value Note  Date From  Date To  Unit  \
# 8          NaN       1400     1800  t/ha
# 21         NaN        800     1500  t/ha
# ...

# %%
Agriculture_Dataset_yield['NGA'].value_counts()
# Out:
# NGA
# Latium                        11
# Paris Basin                   11
# Valley of Oaxaca               7
# Upper Egypt                    6
# Middle Yellow River Valley     6
# Kansai                         6
# Chuuk Islands                  2
# Cambodian Basin                2
# Deccan                         1
# Finger Lakes                   1
# Kachi Plain                    1
# Cahokia                        1
# Konya Plain                    1
# Cuzco                          1
# Oro PNG                        1
# Central Java                   1
# Sogdiana                       1
# Big Island Hawaii              1
# Name: count, dtype: int64

# %%
Agriculture_Dataset_yield['Variable'].unique()
# Out:
# array(['Historical Productivity', 'HIstorical Productivity'], dtype=object)

# %%
Agriculture_Dataset_yield['Value From'].unique()
# Out:
# array(['3.25', '0.672', '1.46', '2.5', '1.345', '16', '10', '1.2',
#        '1.371', '0.5', '1.096', '1.3', '1.55', '1.5', '1.9', '2.1', '2.2',
#        '1', '0.376', '1.296', '1.35', '0.54', '0.23', '0.675', '0.878',
#        '0.405', '0.258', '1.05', '0.75', '0.8', '0.25', '6.5', '0.65',
#        '0.308', '0.773', '1.624', '1.16', '1.933', '2.22', '0.62', '1.07',
#        '1.71', '1.425', '1.665', '1.075', '0.6', '0.7', '1.1', '1.4'],
#       dtype=object)

# %%
Agriculture_Dataset_yield[['Value From', 'Value To']] = Agriculture_Dataset_yield[['Value From', 'Value To']].apply(pd.to_numeric)
Agriculture_Dataset_yield.dtypes
# Out:
# C:\Users\Revalina\AppData\Local\Temp\ipykernel_46148\3782443145.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Agriculture_Dataset_yield[['Value From', 'Value To']] = Agriculture_Dataset_yield[['Value From', 'Value To']].apply(pd.to_numeric)
# NGA             object
# Variable        object
# Value From     float64
# Value To       float64
# Value Note      object
# Date From        int64
# Date To          int64
# Unit            object
# Explanation     object
# dtype: object

# %%
plt.figure(figsize=(20,10))
sns.lineplot(data=Agriculture_Dataset_yield, y="Value From",x='Date From', palette='viridis', hue = 'NGA')
plt.xticks(rotation=90, fontsize=16)
plt.title('Hubungan antara Produktivitas dan NGA sepanjang Waktu', fontsize=16, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Hubungan antara Produktivitas dan NGA sepanjang Waktu')

# %% [markdown]
# Dapat dilihat bahwa 'Chuuk Islands' memiliki produktivitas pertanian tertinggi dan 'Middle Yellow River Valley' memiliki yang terendah.
# Selain itu, dapat dilihat bahwa sebagian besar NGA memiliki produktivitas sekitar 1-4 t/ha.

# %%
Agriculture_Dataset_carb_source = Agriculture_Dataset[(Agriculture_Dataset.Variable == 'Carbohydrate Source 1')]

# %%
Agriculture_Dataset_carb_source.head(10)
# Out:
#                   NGA               Variable    Value From Value To  \
# 0   Big Island Hawaii  Carbohydrate Source 1  sweet potato      NaN
# 12            Cahokia  Carbohydrate Source 1      chenopod      NaN
# 18            Cahokia  Carbohydrate Source 1         maize      NaN
# 22    Cambodian Basin  Carbohydrate Source 1          rice      NaN
# 23    Cambodian Basin  Carbohydrate Source 1          rice      NaN
# 37       Central Java  Carbohydrate Source 1          rice      NaN
# 49      Chuuk Islands  Carbohydrate Source 1    breadfruit      NaN
# 56              Cuzco  Carbohydrate Source 1         maize      NaN
# 70             Deccan  Carbohydrate Source 1        millet      NaN
# 76             Deccan  Carbohydrate Source 1          rice      NaN
#
#    Value Note  Date From  Date To Unit  \
# 0         NaN        750     1800  NaN
# 12        NaN      -1800      800  NaN
# 18        NaN        800     1500  NaN
# 22        NaN      -2500    -1000  NaN
# ...

# %%
plt.figure(figsize=(20,10))
plt.xticks(rotation=90, fontsize=16)
sns.lineplot(x='NGA', y='Date From', data=Agriculture_Dataset_carb_source)
plt.title('Hubungan antara Date From dan NGA', fontsize=16, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Hubungan antara Date From dan NGA')

# %% [markdown]
# - Lena River Valley adalah NGA yang cukup muda atau bahwa data tidak tersedia sebelum tahun 1835 M.
# - Susiana adalah satu-satunya NGA yang memiliki data untuk 10000 SM tersedia.
# - Semua NGA lainnya dimulai antara periode waktu 10000 SM hingga 1835 M.

# %%
plt.figure(figsize=(20,20))
g = sns.catplot(data=Agriculture_Dataset_carb_source, y="Value From",x='NGA', color='red')
plt.xticks(rotation=90, fontsize=16)
g.fig.set_figwidth(20)
g.fig.set_figheight(8)
plt.yticks(fontsize=16)
plt.title('Relation between Type of Carbohydrate and NGA', fontsize=16, fontweight='bold')
# Out:
# C:\Users\Revalina\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Text(0.5, 1.0, 'Relation between Type of Carbohydrate and NGA')

# %% [markdown]
# - Chenopod diproduksi di Cahokia sebagai sumber karbohidrat.
# - Jagung adalah sumber karbohidrat di Cahokia, Cuzco, Finger Lakes, North Colombia, dan Valley of Oaxaca.
# - Beras diproduksi di Cambodian Basin, Central Java, Deccan, Ghanian Coast, Kansai, Kapuasi Basin, Niger Inland Delta, dan Southern China Hills.
# - Chuuk Islands adalah satu-satunya NGA yang memproduksi Breadfruit sebagai sumber karbohidrat.
# - Millets diproduksi di Deccan dan Middle Yellow River Valley.
# - Ghanian Coast menggunakan Yams sebagai sumber karbohidrat.
# - Gandum digunakan sebagai sumber karbohidrat di sebagian besar wilayah, termasuk Kachi plain, Konya plain, Latium, Middle Yellow River Valley, Paris Basin, Sogdiana, Susiana, Upper Egypt, dan Yemeni Coastal Plain.

# %%
plt.figure(figsize=(20,10))
sns.countplot(data=Agriculture_Dataset_carb_source, x="Value From", palette='rainbow')
plt.xticks(fontsize=14)
plt.title('Count of Different Carbohydrate Sources across NGAs', fontsize=18, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Count of Different Carbohydrate Sources across NGAs')

# %% [markdown]
# Beras dan gandum adalah sumber karbohidrat paling populer di berbagai NGA

# %%
Agriculture_Dataset_irrigation = Agriculture_Dataset[(Agriculture_Dataset.Variable == 'Irrigation Coefficient')]
Agriculture_Dataset_irrigation.head(5)
Agriculture_Dataset_irrigation[['Value From', 'Value To']] = Agriculture_Dataset_irrigation[['Value From', 'Value To']].apply(pd.to_numeric)
# Out:
# C:\Users\Revalina\AppData\Local\Temp\ipykernel_46148\2192047790.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Agriculture_Dataset_irrigation[['Value From', 'Value To']] = Agriculture_Dataset_irrigation[['Value From', 'Value To']].apply(pd.to_numeric)

# %%
plt.figure(figsize=(20,15))
sns.barplot(data=Agriculture_Dataset_irrigation, x="NGA", y="Value From", palette="viridis")
plt.xticks(fontsize=15, rotation = 90)
plt.yticks(fontsize=15)
plt.title('Coefficient of Irrigation across NGAs', fontsize=18, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Coefficient of Irrigation across NGAs')

# %% [markdown]
# - Deccan, Kachi Plain, Kansai Plain, Susiana, dan Yemeni Coastal Plain memiliki koefisien irigasi tertinggi.
# - Latium dan Sogdiana memiliki koefisien irigasi sebesar 1, menunjukkan bahwa terdapat curah hujan yang cukup tinggi di wilayah ini dan irigasi tidak memberikan perbedaan signifikan dalam produktivitas tanaman.
# - Dari 30 NGA unik yang tersedia, hanya ada 15 di antaranya yang menggunakan irigasi pada setiap waktu tertentu. Hal ini mungkin terkait dengan kondisi cuaca di berbagai NGA.

# %%
Agriculture_Dataset_fertilizer = Agriculture_Dataset[(Agriculture_Dataset.Variable == 'Fertilizer Coefficient')]
Agriculture_Dataset_fertilizer.head(5)
Agriculture_Dataset_fertilizer[['Value From', 'Value To']] = Agriculture_Dataset_fertilizer[['Value From', 'Value To']].apply(pd.to_numeric)
# Out:
# C:\Users\Revalina\AppData\Local\Temp\ipykernel_46148\2294059775.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Agriculture_Dataset_fertilizer[['Value From', 'Value To']] = Agriculture_Dataset_fertilizer[['Value From', 'Value To']].apply(pd.to_numeric)

# %%
plt.figure(figsize=(20,15))
sns.barplot(data=Agriculture_Dataset_fertilizer, x="NGA", y="Value From", palette="terrain")
plt.xticks(fontsize=15, rotation = 90)
plt.yticks(fontsize=15)
plt.title('Coefficient of Fertilizer across NGAs', fontsize=18, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Coefficient of Fertilizer across NGAs')

# %% [markdown]
# - 23 dari 30 di antaranya menggunakan pupuk dalam pertanian mereka.
# - Koefisien Pupuk tertinggi sekitar 1,90 ada di Ghanian Coast.
# - Koefisien Deccan, Konya Plain, dan Paris Basin bervariasi dari waktu ke waktu. Hal ini mungkin disebabkan oleh jenis sumber pupuk yang digunakan pada berbagai waktu.
# - Hampir semua koefisien pupuk lebih besar dari 1, menunjukkan bahwa penggunaan pupuk membantu meningkatkan produktivitas tanaman.

# %% [markdown]
# # Kesimpulan

# %% [markdown]
# Upaya untuk mengestimasi produktivitas pertanian secara global tergolong cukup rumit dari awal masa dikenalnya pertanian.  DIperlukan penelitian lebih lanjut dalam mengidentifikasi lebih lanjut setia NGA (National Geographic Area) dengan pertimbangan iklim dan lingkungan yang berbeda. Namun, dapat ditarik pernyataan bahwa penggunaan pupuk tampaknya memberikan kontribusi positif yang besar terhadap produktivitas tanaman.
